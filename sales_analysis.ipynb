# %% [markdown]
# ## Import all libraries

# %%
import pandas as pd

# %% [markdown]
# ## create dataframes for each csv files individually

# %%
df1=pd.read_csv('Sales_April_2019.csv')
df1
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df2=pd.read_csv('Sales_August_2019.csv')
df2
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       236670            Wired Headphones                2      11.99
# 1       236671  Bose SoundSport Headphones                1      99.99
# 2       236672                      iPhone                1      700.0
# 3       236673       AA Batteries (4-pack)                2       3.84
# 4       236674       AA Batteries (4-pack)                2       3.84
# ...        ...                         ...              ...        ...
# 12006   248146  Bose SoundSport Headphones                1      99.99
# 12007   248147      AAA Batteries (4-pack)                3       2.99
# 12008   248148       AA Batteries (4-pack)                1       3.84
# 12009   248149        USB-C Charging Cable                1      11.95
# 12010   248150       AA Batteries (4-pack)                1       3.84
#
#            Order Date                         Purchase Address
# ...

# %%
df3=pd.read_csv('Sales_December_2019.csv')
df3
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1       1700
# 1       295666          LG Washing Machine                1      600.0
# 2       295667        USB-C Charging Cable                1      11.95
# 3       295668            27in FHD Monitor                1     149.99
# 4       295669        USB-C Charging Cable                1      11.95
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df4=pd.read_csv('Sales_February_2019.csv')
df4
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       150502                    iPhone                1        700
# 1       150503     AA Batteries (4-pack)                1       3.84
# 2       150504    27in 4K Gaming Monitor                1     389.99
# 3       150505  Lightning Charging Cable                1      14.95
# 4       150506     AA Batteries (4-pack)                2       3.84
# ...        ...                       ...              ...        ...
# 12031   162004  Apple Airpods Headphones                1        150
# 12032   162005    AAA Batteries (4-pack)                2       2.99
# 12033   162006      USB-C Charging Cable                1      11.95
# 12034   162007      USB-C Charging Cable                1      11.95
# 12035   162008          27in FHD Monitor                1     149.99
#
#            Order Date                         Purchase Address
# 0      02/18/19 01:35        866 Spruce St, Portland, ME 04101
# ...

# %%
df5=pd.read_csv('Sales_January_2019.csv')
df5
# Out:
#      Order ID                   Product Quantity Ordered Price Each  \
# 0      141234                    iPhone                1        700
# 1      141235  Lightning Charging Cable                1      14.95
# 2      141236          Wired Headphones                2      11.99
# 3      141237          27in FHD Monitor                1     149.99
# 4      141238          Wired Headphones                1      11.99
# ...       ...                       ...              ...        ...
# 9718   150497              20in Monitor                1     109.99
# 9719   150498          27in FHD Monitor                1     149.99
# 9720   150499           ThinkPad Laptop                1     999.99
# 9721   150500    AAA Batteries (4-pack)                2       2.99
# 9722   150501              Google Phone                1        600
#
#           Order Date                       Purchase Address
# 0     01/22/19 21:25        944 Walnut St, Boston, MA 02215
# ...

# %%
df6=pd.read_csv('Sales_July_2019.csv')
df6
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 0       222910  Apple Airpods Headphones                1        150
# 1       222911             Flatscreen TV                1        300
# 2       222912     AA Batteries (4-pack)                1       3.84
# 3       222913     AA Batteries (4-pack)                1       3.84
# 4       222914    AAA Batteries (4-pack)                5       2.99
# ...        ...                       ...              ...        ...
# 14366   236665          Wired Headphones                1      11.99
# 14367   236666              20in Monitor                1     109.99
# 14368   236667    AAA Batteries (4-pack)                1       2.99
# 14369   236668          Wired Headphones                1      11.99
# 14370   236669    AAA Batteries (4-pack)                1       2.99
#
#            Order Date                      Purchase Address
# 0      07/26/19 16:51       389 South St, Atlanta, GA 30301
# ...

# %%
df7=pd.read_csv('Sales_June_2019.csv')
df7
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       209921        USB-C Charging Cable                1      11.95
# 1       209922          Macbook Pro Laptop                1     1700.0
# 2       209923             ThinkPad Laptop                1     999.99
# 3       209924            27in FHD Monitor                1     149.99
# 4       209925  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 13617   222905      AAA Batteries (4-pack)                1       2.99
# 13618   222906            27in FHD Monitor                1     149.99
# 13619   222907        USB-C Charging Cable                1      11.95
# 13620   222908        USB-C Charging Cable                1      11.95
# 13621   222909      AAA Batteries (4-pack)                1       2.99
#
#            Order Date                       Purchase Address
# ...

# %%
df8=pd.read_csv('Sales_March_2019.csv')
df8
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       162009                      iPhone                1        700
# 1       162009    Lightning Charging Cable                1      14.95
# 2       162009            Wired Headphones                2      11.99
# 3       162010  Bose SoundSport Headphones                1      99.99
# 4       162011      34in Ultrawide Monitor                1     379.99
# ...        ...                         ...              ...        ...
# 15221   176554    Lightning Charging Cable                1      14.95
# 15222   176555            27in FHD Monitor                1     149.99
# 15223   176556      AAA Batteries (4-pack)                3       2.99
# 15224   176557                      iPhone                1        700
# 15225   176557    Lightning Charging Cable                1      14.95
#
#            Order Date                           Purchase Address
# ...

# %%
df9=pd.read_csv('Sales_May_2019.csv')
df9
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       194095            Wired Headphones                1      11.99
# 1       194096       AA Batteries (4-pack)                1       3.84
# 2       194097            27in FHD Monitor                1     149.99
# 3       194098            Wired Headphones                1      11.99
# 4       194099      AAA Batteries (4-pack)                2       2.99
# ...        ...                         ...              ...        ...
# 16630   209916  Bose SoundSport Headphones                1      99.99
# 16631   209917            Wired Headphones                1      11.99
# 16632   209918      AAA Batteries (4-pack)                2       2.99
# 16633   209919        USB-C Charging Cable                1      11.95
# 16634   209920             ThinkPad Laptop                1     999.99
#
#            Order Date                         Purchase Address
# ...

# %%
df10=pd.read_csv('Sales_November_2019.csv')
df10
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1      150.0
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#            Order Date                      Purchase Address
# ...

# %%
df11=pd.read_csv('Sales_October_2019.csv')
df11
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       259358  34in Ultrawide Monitor                1     379.99
# 1       259359  27in 4K Gaming Monitor                1     389.99
# 2       259360  AAA Batteries (4-pack)                2       2.99
# 3       259361        27in FHD Monitor                1     149.99
# 4       259362        Wired Headphones                1      11.99
# ...        ...                     ...              ...        ...
# 20374   278792   AA Batteries (4-pack)                1       3.84
# 20375   278793        Wired Headphones                1      11.99
# 20376   278794   AA Batteries (4-pack)                1       3.84
# 20377   278795                  iPhone                1        700
# 20378   278796        Wired Headphones                1      11.99
#
#            Order Date                           Purchase Address
# 0      10/28/19 10:56            609 Cherry St, Dallas, TX 75001
# ...

# %%
df12=pd.read_csv('Sales_September_2019.csv')
df12
# Out:
#       Order ID                 Product Quantity Ordered Price Each  \
# 0       248151   AA Batteries (4-pack)                4       3.84
# 1       248152    USB-C Charging Cable                2      11.95
# 2       248153    USB-C Charging Cable                1      11.95
# 3       248154        27in FHD Monitor                1     149.99
# 4       248155    USB-C Charging Cable                1      11.95
# ...        ...                     ...              ...        ...
# 11681   259353  AAA Batteries (4-pack)                3       2.99
# 11682   259354                  iPhone                1        700
# 11683   259355                  iPhone                1        700
# 11684   259356  34in Ultrawide Monitor                1     379.99
# 11685   259357    USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      09/17/19 14:44      380 North St, Los Angeles, CA 90001
# ...

# %% [markdown]
# ## Concatenate those dataframes into a single Dataframe using pd.concat()

# %%
all_month_data=pd.concat([df5,df4,df8,df1,df9,df7,df6,df2,df12,df11,df10,df3])
all_month_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
type(all_month_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## write the dataframe into a single csv,excel file using .to_csv(),.to_excel()

# %%
all_month_data.to_csv('all_month_sales_data.csv',index=False)

# %%
all_month_data.to_excel('all_month_sales_data.xlsx',index=False)

# %% [markdown]
# ## Cleaning the data
# - There are one or many rows of NaN
#     - Search the entire dataframe with rows having NaN using isna()
#     - remove those rows from dataframe using dropna()
# - Then call the dataframe

# %%
import numpy as np

# %%
all_month_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
nan_values=all_month_data[all_month_data.isna().any(axis=1)]
nan_values
# Out:
#       Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 664        NaN     NaN              NaN        NaN        NaN              NaN
# 678        NaN     NaN              NaN        NaN        NaN              NaN
# 797        NaN     NaN              NaN        NaN        NaN              NaN
# 876        NaN     NaN              NaN        NaN        NaN              NaN
# 1299       NaN     NaN              NaN        NaN        NaN              NaN
# ...        ...     ...              ...        ...        ...              ...
# 22945      NaN     NaN              NaN        NaN        NaN              NaN
# 22962      NaN     NaN              NaN        NaN        NaN              NaN
# 23309      NaN     NaN              NaN        NaN        NaN              NaN
# 23996      NaN     NaN              NaN        NaN        NaN              NaN
# 24730      NaN     NaN              NaN        NaN        NaN              NaN
#
# [545 rows x 6 columns]

# %%
all_month_data=all_month_data.dropna()
all_month_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       141234                      iPhone                1        700
# 1       141235    Lightning Charging Cable                1      14.95
# 2       141236            Wired Headphones                2      11.99
# 3       141237            27in FHD Monitor                1     149.99
# 4       141238            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
null_values=all_month_data[all_month_data.isnull().any(axis=1)]
null_values
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
all_data=all_month_data
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# # Augment the dataframe with some extra columns to get detail info

# %% [markdown]
# ## Task 1:
# - Create 'Month' column in dataframe for each 'Order Date'

# %%
all_data=all_data[all_data['Order Date'].str[0:2]!='Or']
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        Order Date                       Purchase Address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %%
all_data['Month']=all_data['Order Date'].str[0:2]
all_data['Month']=all_data['Month'].astype('int32')
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\676854105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month']=all_data['Order Date'].str[0:2]
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\676854105.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Month']=all_data['Month'].astype('int32')
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   141234                    iPhone                1        700
# ...

# %% [markdown]
# ## Task 2:
# - Add 'Sales' column in the dataframe by multiplying 'Price Each' and 'Quantity Ordered'

# %%
all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype('int32')
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\1806496514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype('int32')
#   Order ID                   Product  Quantity Ordered Price Each  \
# 0   141234                    iPhone                 1        700
# 1   141235  Lightning Charging Cable                 1      14.95
# 2   141236          Wired Headphones                 2      11.99
# 3   141237          27in FHD Monitor                 1     149.99
# 4   141238          Wired Headphones                 1      11.99
#
#        Order Date                       Purchase Address  Month
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215      1
# ...

# %%
all_data=all_data[all_data['Price Each']!='14.95']
all_data
# Out:
#       Order ID                     Product  Quantity Ordered Price Each  \
# 0       141234                      iPhone                 1        700
# 2       141236            Wired Headphones                 2      11.99
# 3       141237            27in FHD Monitor                 1     149.99
# 4       141238            Wired Headphones                 1      11.99
# 5       141239      AAA Batteries (4-pack)                 1       2.99
# ...        ...                         ...               ...        ...
# 25111   319665                      iPhone                 1        700
# 25113   319667       AA Batteries (4-pack)                 2       3.84
# 25114   319668             Vareebadd Phone                 1        400
# 25115   319669            Wired Headphones                 1      11.99
# 25116   319670  Bose SoundSport Headphones                 1      99.99
#
#            Order Date                        Purchase Address  Month
# ...

# %% [markdown]
# ## Convert the required columns to correct data type

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each']=pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ## find Sales for each Order ID
# - Ways to do:
#     - Multiply 'Quantity Ordered' with 'Price Each'

# %%
#all_data.head()
all_data['Sales']=all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each  \
# 0   141234                  iPhone                 1      700.00
# 2   141236        Wired Headphones                 2       11.99
# 3   141237        27in FHD Monitor                 1      149.99
# 4   141238        Wired Headphones                 1       11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99
#
#        Order Date                        Purchase Address  Month   Sales
# 0  01/22/19 21:25         944 Walnut St, Boston, MA 02215      1  700.00
# 2  01/17/19 13:33   538 Adams St, San Francisco, CA 94016      1   23.98
# 3  01/05/19 20:33      738 10th St, Los Angeles, CA 90001      1  149.99
# 4  01/25/19 11:59           387 10th St, Austin, TX 73301      1   11.99
# 5  01/29/19 20:22  775 Willow St, San Francisco, CA 94016      1    2.99

# %% [markdown]
# ## Reorder the columns in DataFrame

# %%
all_data=all_data[['Order ID','Product','Quantity Ordered','Price Each','Sales','Order Date','Month','Purchase Address']]
all_data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234                      iPhone                 1      700.00
# 2       141236            Wired Headphones                 2       11.99
# 3       141237            27in FHD Monitor                 1      149.99
# 4       141238            Wired Headphones                 1       11.99
# 5       141239      AAA Batteries (4-pack)                 1        2.99
# ...        ...                         ...               ...         ...
# 25111   319665                      iPhone                 1      700.00
# 25113   319667       AA Batteries (4-pack)                 2        3.84
# 25114   319668             Vareebadd Phone                 1      400.00
# 25115   319669            Wired Headphones                 1       11.99
# 25116   319670  Bose SoundSport Headphones                 1       99.99
#
#         Sales      Order Date  Month                        Purchase Address
# ...

# %% [markdown]
# ## Q1.   What was the best month for Sales ? What was the amount earned ?

# %%
all_data.groupby('Month').sum()
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                  9748  1795756.93  1804989.48
# 2                 11950  2168029.47  2179612.37
# 3                 15132  2765000.48  2779099.03
# 4                 18185  3334736.17  3355193.89
# 5                 16592  3106271.63  3121585.50
# 6                 13566  2538643.81  2552581.61
# 7                 14261  2607199.31  2620701.31
# 8                 12005  2210058.27  2222895.03
# 9                 11677  2065138.49  2076151.73
# 10                20131  3679345.93  3698275.48
# 11                17588  3149998.03  3166563.70
# 12                25027  4545165.06  4567292.69

# %%
results=all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months=range(1,13)
plt.xticks(months)
plt.xlabel('Month number')
plt.ylabel('Sales amount($USD millions)')
plt.bar(months,results['Sales'])
plt.show()

# %% [markdown]
# ## Q2. Which city had the highest number of Sales?

# %%
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address
# 0  01/22/19 21:25      1         944 Walnut St, Boston, MA 02215
# 2  01/17/19 13:33      1   538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33      1      738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59      1           387 10th St, Austin, TX 73301
# 5  01/29/19 20:22      1  775 Willow St, San Francisco, CA 94016

# %% [markdown]
# ### Steps followed:
# - First Augment the data by adding new column 'city' using given column 'Purchase Address'
#     - Check the data type of 'city' column
#     - If there are errors,then clean them
# - Secondly, Augment the data by adding new column 'State Code' using given column 'Purchase Address'
# - Thirdly Augment the data by adding new column 'Zip Code' using given column 'Purchase Address'
# - Fourthly Augment the data by adding new column 'Street' using given column 'Purchase Address'
# - First Augment the data by adding new column 'city' using given column 'Purchase Address'
# - Then visualize the data with bar chart

# %%
def get_city(address):
    return address.split(',')[1]
all_data['City']=all_data['Purchase Address'].apply(lambda x: get_city(x))
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2677736552.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['City']=all_data['Purchase Address'].apply(lambda x: get_city(x))
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address  \
# ...

# %%
def get_state(address):
    return address.split(', ')[2].split(' ')[0]
all_data['State Code']=all_data['Purchase Address'].apply(lambda x: get_state(x))
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2630791649.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['State Code']=all_data['Purchase Address'].apply(lambda x: get_state(x))
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address  \
# ...

# %%
def get_zipcode(address):
    return address.split(', ')[2].split(' ')[1]
all_data['Zip Code']=all_data['Purchase Address'].apply(lambda x: get_zipcode(x))
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\3555859728.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Zip Code']=all_data['Purchase Address'].apply(lambda x: get_zipcode(x))
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address  \
# ...

# %%
def get_street(address):
    return address.split(', ')[0]
all_data['Street']=all_data['Purchase Address'].apply(lambda x: get_street(x))
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2781105805.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Street']=all_data['Purchase Address'].apply(lambda x: get_street(x))
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address  \
# ...

# %%
all_data
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       141234                      iPhone                 1      700.00
# 2       141236            Wired Headphones                 2       11.99
# 3       141237            27in FHD Monitor                 1      149.99
# 4       141238            Wired Headphones                 1       11.99
# 5       141239      AAA Batteries (4-pack)                 1        2.99
# ...        ...                         ...               ...         ...
# 25111   319665                      iPhone                 1      700.00
# 25113   319667       AA Batteries (4-pack)                 2        3.84
# 25114   319668             Vareebadd Phone                 1      400.00
# 25115   319669            Wired Headphones                 1       11.99
# 25116   319670  Bose SoundSport Headphones                 1       99.99
#
#         Sales      Order Date  Month                        Purchase Address  \
# ...

# %%
all_data.groupby('City').sum()
# Out:
#                 Quantity Ordered  Price Each       Sales   Month
# City
#  Atlanta                   14723  2753685.90  2767407.53   92588
#  Austin                     9846  1791529.96  1800042.10   61292
#  Boston                    20037  3602680.92  3624401.56  124467
#  Dallas                    14866  2726913.82  2740108.60   92616
#  Los Angeles               29517  5368930.83  5396179.40  183498
#  New York City             24891  4592598.88  4618854.48  155637
#  Portland                  12522  2286294.22  2297602.16   77451
#  San Francisco             44682  8134110.44  8179126.76  278984
#  Seattle                   14778  2708598.61  2721219.23   93022

# %%
import matplotlib.pyplot as plt
results_2=all_data.groupby('City').sum()
cities=[city for city,df in all_data.groupby('City')]
plt.bar(cities,results_2['Sales'])
plt.xticks(cities,rotation='vertical',size=8)
plt.xlabel('Cities')
plt.ylabel('Sales(in $M)')
plt.show()
# SanFransisco had maximum Sales of more than $8Millions

# %% [markdown]
# ###  Q3. What time should we display ads so as to maximize the likelihood of customer's buying product ?

# %%
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#        Order Date  Month                        Purchase Address  \
# 0  01/22/19 21:25      1         944 Walnut St, Boston, MA 02215
# 2  01/17/19 13:33      1   538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33      1      738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59      1           387 10th St, Austin, TX 73301
# 5  01/29/19 20:22      1  775 Willow St, San Francisco, CA 94016
#
#              City State Code Zip Code         Street
# 0          Boston         MA    02215  944 Walnut St
# ...

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2539822065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#            Order Date  Month                        Purchase Address  \
# 0 2019-01-22 21:25:00      1         944 Walnut St, Boston, MA 02215
# 2 2019-01-17 13:33:00      1   538 Adams St, San Francisco, CA 94016
# 3 2019-01-05 20:33:00      1      738 10th St, Los Angeles, CA 90001
# 4 2019-01-25 11:59:00      1           387 10th St, Austin, TX 73301
# 5 2019-01-29 20:22:00      1  775 Willow St, San Francisco, CA 94016
#
#              City State Code Zip Code         Street
# 0          Boston         MA    02215  944 Walnut St
# ...

# %%
all_data['Order Date']
# Out:
# 0       2019-01-22 21:25:00
# 2       2019-01-17 13:33:00
# 3       2019-01-05 20:33:00
# 4       2019-01-25 11:59:00
# 5       2019-01-29 20:22:00
#                 ...
# 25111   2019-12-15 11:13:00
# 25113   2019-12-01 12:01:00
# 25114   2019-12-09 06:43:00
# 25115   2019-12-03 10:39:00
# 25116   2019-12-21 21:45:00
# Name: Order Date, Length: 164292, dtype: datetime64[ns]

# %%
all_data['Hour']=all_data['Order Date'].dt.hour
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\418966418.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Hour']=all_data['Order Date'].dt.hour
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#            Order Date  Month                        Purchase Address  \
# ...

# %%
all_data['Minutes']=all_data['Order Date'].dt.minute
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2392613242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Minutes']=all_data['Order Date'].dt.minute
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#            Order Date  Month                        Purchase Address  \
# ...

# %%
all_data['Seconds']=all_data['Order Date'].dt.second
all_data.head()
# Out:
# C:\Users\SHANKHANEEL\AppData\Local\Temp\ipykernel_13752\2329926995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['Seconds']=all_data['Order Date'].dt.second
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#            Order Date  Month                        Purchase Address  \
# ...

# %%
all_data=all_data[['Order ID','Product','Quantity Ordered','Price Each','Sales','Order Date','Month','Hour','Minutes','Seconds',
                   'Purchase Address','City','State Code','Zip Code','Street' 
                  ]]
all_data.head()
# Out:
#   Order ID                 Product  Quantity Ordered  Price Each   Sales  \
# 0   141234                  iPhone                 1      700.00  700.00
# 2   141236        Wired Headphones                 2       11.99   23.98
# 3   141237        27in FHD Monitor                 1      149.99  149.99
# 4   141238        Wired Headphones                 1       11.99   11.99
# 5   141239  AAA Batteries (4-pack)                 1        2.99    2.99
#
#            Order Date  Month  Hour  Minutes  Seconds  \
# 0 2019-01-22 21:25:00      1    21       25        0
# 2 2019-01-17 13:33:00      1    13       33        0
# 3 2019-01-05 20:33:00      1    20       33        0
# 4 2019-01-25 11:59:00      1    11       59        0
# 5 2019-01-29 20:22:00      1    20       22        0
#
#                          Purchase Address            City State Code Zip Code  \
# 0         944 Walnut St, Boston, MA 02215          Boston         MA    02215
# ...

# %%
import matplotlib.pyplot as plt
orders=all_data.groupby(['Hour']).count()

# %%
hours=[hour for hour,df in all_data.groupby('Hour')]
orders=all_data.groupby(['Hour']).count()
plt.xlabel('Hours')
plt.ylabel('Count of Orders')
plt.plot(hours,orders)
plt.xticks(hours)
plt.grid()
plt.show()

## so we should try to give ads at 11am and 7pm , to increase the likelyhood of Purchase
